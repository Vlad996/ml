# %% [markdown]
# **Лабораторная работа №1. Новичков В.С. 15-В-2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cneos_fireball_data.csv')

# %%
df.head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0            2017-07-31 22:01:35           24.7N           118.5W
# 1            2017-07-23 06:12:38            6.6S            69.7W
# 2            2017-07-13 09:30:36           23.1N            60.7E
# 3            2017-06-30 14:26:45           34.3S           134.5E
# 4            2017-06-23 20:21:55           57.0N           143.7E
#
#    Altitude (km)  Velocity (km/s)    vx    vy    vz  \
# 0            NaN              NaN   NaN   NaN   NaN
# 1           38.0             17.2  -0.4   8.7 -14.8
# 2           35.0             13.7 -10.0  -6.5  -6.8
# 3           20.0             15.2  10.9  -9.7   4.2
# 4           35.1             24.3  17.7  13.1 -10.3
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0               5.800000e+10                                 0.19
# 1               3.500000e+10                                 0.12
# ...

# %%
df.tail()
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 714            1993-11-29 17:48:41           26.5N            78.3E
# 715            1993-10-31 03:39:27           51.3N           100.9W
# 716            1991-10-04 09:22:47           78.7N             6.3E
# 717            1990-10-01 03:51:47            7.5N           142.8E
# 718            1988-04-15 03:03:10            4.1S           124.3E
#
#      Altitude (km)  Velocity (km/s)  vx  vy  vz  Total Radiated Energy (J)  \
# 714            NaN              NaN NaN NaN NaN               2.600000e+10
# 715            NaN              NaN NaN NaN NaN               4.000000e+10
# 716            NaN              NaN NaN NaN NaN               5.500000e+11
# 717            NaN              NaN NaN NaN NaN               2.500000e+12
# 718            NaN              NaN NaN NaN NaN               7.580000e+12
#
#      Calculated Total Impact Energy (kt)
# 714                                0.092
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 10 columns):
# Peak Brightness Date/Time (UT)         719 non-null object
# Latitude (deg.)                        539 non-null object
# Longitude (deg.)                       539 non-null object
# Altitude (km)                          307 non-null float64
# Velocity (km/s)                        157 non-null float64
# vx                                     157 non-null float64
# vy                                     157 non-null float64
# vz                                     157 non-null float64
# Total Radiated Energy (J)              719 non-null float64
# Calculated Total Impact Energy (kt)    719 non-null float64
# dtypes: float64(7), object(3)
# memory usage: 56.2+ KB

# %%
df.describe()
# Out:
#        Altitude (km)  Velocity (km/s)          vx          vy          vz  \
# count     307.000000       157.000000  157.000000  157.000000  157.000000
# mean       36.511726        17.950318    0.310828   -2.388535   -1.031847
# std        10.649462         6.057382   10.825425   11.415896   10.419010
# min        15.200000         9.800000  -35.400000  -43.500000  -28.700000
# 25%        29.600000        13.700000   -7.300000  -11.200000   -9.100000
# 50%        35.200000        16.900000    0.100000   -2.300000    0.300000
# 75%        40.700000        19.800000    9.100000    4.800000    6.700000
# max        74.000000        49.000000   21.500000   25.800000   23.700000
#
#        Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# count               7.190000e+02                           719.000000
# mean                8.812462e+11                             1.387638
# std                 1.405769e+13                            16.598496
# ...

# %%
df.shape
# Out:
# (719, 10)

# %%
df0 = df.copy()
df0 = df0.drop_duplicates()
df0 = df0.dropna()
df0 = df0.reset_index(drop=True)

# %%
df0.head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0            2017-07-23 06:12:38            6.6S            69.7W
# 1            2017-07-13 09:30:36           23.1N            60.7E
# 2            2017-06-30 14:26:45           34.3S           134.5E
# 3            2017-06-23 20:21:55           57.0N           143.7E
# 4            2017-06-20 13:41:32           54.2S           133.0E
#
#    Altitude (km)  Velocity (km/s)    vx    vy    vz  \
# 0           38.0             17.2  -0.4   8.7 -14.8
# 1           35.0             13.7 -10.0  -6.5  -6.8
# 2           20.0             15.2  10.9  -9.7   4.2
# 3           35.1             24.3  17.7  13.1 -10.3
# 4           33.3             13.6   8.7  -5.7   8.8
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0               3.500000e+10                                 0.12
# 1               7.300000e+10                                 0.23
# ...

# %%
df0.tail()
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 150            2004-04-22 04:21:49           44.3S            83.3E
# 151            2004-04-06 03:24:49           12.0S           162.8E
# 152            2003-11-10 13:54:06           64.5S           136.2E
# 153            2003-09-27 12:59:02           21.0N            86.6E
# 154            1998-01-04 23:00:27           35.1S            33.4E
#
#      Altitude (km)  Velocity (km/s)    vx    vy    vz  \
# 150           29.6             16.3   8.5 -12.1  -6.8
# 151           35.0             25.6  10.5 -23.2  -2.9
# 152           23.0             20.1  14.8  -8.7  10.4
# 153           26.0             18.2  -1.0  -5.4 -17.3
# 154           30.0             17.1   6.0 -10.6  12.0
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 150               6.240000e+11                                 1.50
# 151               4.330000e+11                                 1.10
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 10 columns):
# Peak Brightness Date/Time (UT)         155 non-null object
# Latitude (deg.)                        155 non-null object
# Longitude (deg.)                       155 non-null object
# Altitude (km)                          155 non-null float64
# Velocity (km/s)                        155 non-null float64
# vx                                     155 non-null float64
# vy                                     155 non-null float64
# vz                                     155 non-null float64
# Total Radiated Energy (J)              155 non-null float64
# Calculated Total Impact Energy (kt)    155 non-null float64
# dtypes: float64(7), object(3)
# memory usage: 12.2+ KB

# %%
df0.describe()
# Out:
#        Altitude (km)  Velocity (km/s)          vx          vy          vz  \
# count     155.000000       155.000000  155.000000  155.000000  155.000000
# mean       33.579355        17.984516    0.401290   -2.403226   -1.141290
# std         7.920512         6.085923   10.854725   11.463264   10.396726
# min        15.200000         9.800000  -35.400000  -43.500000  -28.700000
# 25%        27.950000        13.750000   -7.250000  -11.250000   -9.100000
# 50%        33.300000        16.900000    0.100000   -2.300000    0.300000
# 75%        38.150000        19.850000    9.150000    4.700000    6.650000
# max        59.300000        49.000000   21.500000   25.800000   23.700000
#
#        Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# count               1.550000e+02                           155.000000
# mean                3.251239e+12                             4.483742
# std                 3.017594e+13                            35.512239
# ...

# %%
df0.shape
# Out:
# (155, 10)

# %% [markdown]
# ** 1. Определите местоположение появления метеорита с наибольшим количеством высвободившейся энергии.**

# %%
df1 = df0.copy()
df1.sort_values('Total Radiated Energy (J)',ascending=False,inplace=True)
df1[:1][['Latitude (deg.)','Longitude (deg.)','Altitude (km)','Total Radiated Energy (J)']]
# Out:
#    Latitude (deg.) Longitude (deg.)  Altitude (km)  Total Radiated Energy (J)
# 77           54.8N            61.1E           23.3               3.750000e+14

# %% [markdown]
# ** 2. Определите метеорит с максимальной и минимальной скоростью.**

# %%
df2 = df0.copy()
df2.sort_values('Velocity (km/s)',ascending=False,inplace=True)
df2.iloc[[1,-1]]
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 67             2014-01-08 17:05:34            1.3S           147.6E
# 119            2008-07-01 17:40:19           37.1N           115.7W
#
#      Altitude (km)  Velocity (km/s)   vx    vy    vz  \
# 67            18.7             44.8 -3.4 -43.5 -10.3
# 119           36.1              9.8  2.8   1.7  -9.2
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 67                3.100000e+10                                 0.11
# 119               3.600000e+10                                 0.12

# %% [markdown]
# ** 3. Определите место максимальной концентрации метеоритов.**

# %%
def convert_latitude(s):
    """Convert latitude in degrees N/S to polar angle in radians."""
    try:
        if s[-1] == 'S':
            thetap = -float(s[:-1])
        else:
            thetap = float(s[:-1])
    except TypeError:
        return np.nan
    return np.pi/2 - np.radians(thetap)

def convert_longitude(s):
    """Convert longitude in degrees E/W to azimuthal angle in radians."""
    try:
        if s[-1] == 'E':
            phi = -float(s[:-1])
        else:
            phi = float(s[:-1])
    except TypeError:
        return np.nan
    return np.radians(phi)

def get_bin_centres(bin_list):
    """Return the histogram bin centres given the bin edges."""
    return (bin_list[:-1] + bin_list[1:]) / 2

# Latitude: convert to polar angle in radians and discard NaNs.
theta = df['Latitude (deg.)'].apply(convert_latitude)
theta = theta[~np.isnan(theta)]
theta_bins = np.linspace(0, np.pi, 10)
theta_counts, theta_bins = np.histogram(theta, theta_bins)
theta_bins = get_bin_centres(theta_bins)

# Latitude: convert to azimuthal angle in radians and discard NaNs.
phi = df['Longitude (deg.)'].apply(convert_longitude)
phi = phi[~np.isnan(phi)]
phi_bins = np.linspace(-np.pi, np.pi, 10)
phi_counts, phi_bins = np.histogram(phi, phi_bins)
phi_bins = get_bin_centres(phi_bins)

# Figure dimensions and subplots; common styling parameters.
width, height, dpi = 600, 450, 72
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(width/dpi, height/dpi),
                       dpi=dpi)
bar_kwargs = {'linewidth': 0, 'alpha': 0.5, 'align': 'center'}

# Latitude histogram.
theta_bar_width = 180/len(theta_bins) * 0.8
weighted_theta = theta_counts/np.sin(theta_bins)
ax[0,0].bar(np.degrees(theta_bins), weighted_theta,
            width=theta_bar_width, color='m', **bar_kwargs)
ax[0,0].axhline(sum(weighted_theta)/len(theta_bins), c='k', lw=2)
ax[0,0].set_xticks([0, 30, 60, 90, 120, 150, 180])
ax[0,0].set_xticklabels(['90N', '60N', '30N', '0', '30S', '60S', '90S'])
ax[0,0].set_title('Latitude')

# Longitude histogram.
phi_bar_width = theta_bar_width * 2
ax[0,1].bar(np.degrees(phi_bins), phi_counts, width=phi_bar_width,
            color='m', **bar_kwargs)
ax[0,1].set_xlim(-180, 180)
ax[0,1].axhline(len(phi)/len(phi_bins), c='k', lw=2)
ax[0,1].set_xticks([-180, -120, -60, 0, 60, 120, 180])
ax[0,1].set_xticklabels(['180E', '120E', '60E', '0', '60W', '120W', '180W'])
ax[0,1].set_title('Longitude')

plt.show()

# %% [markdown]
# ** 4. Определите время года, в которое вероятность появления метеоритов максимальна. Постройте график.**

# %%
def func4(self):
    return str(self['Peak Brightness Date/Time (UT)'])[5:7]

df4 = df.copy()
df4['Peak Brightness Date/Time (UT)'] = df.apply(func4,axis=1)
df4 = df4.groupby('Peak Brightness Date/Time (UT)')[['Peak Brightness Date/Time (UT)']].count()
lst41 = ['Winter','Spring','Summer','Autumn']
lst42 = [(df4.iat[0,0]+df4.iat[1,0]+df4.iat[11,0])/len(df),(df4.iat[2,0]+df4.iat[3,0]+df4.iat[4,0])/len(df),(df4.iat[5,0]+df4.iat[6,0]+df4.iat[7,0])/len(df),(df4.iat[8,0]+df4.iat[9,0]+df4.iat[10,0])/len(df)]
print(str(lst41[lst42.index(max(lst42))]) + ": " + str(max(lst42)))
df42 = pd.DataFrame(dict([('Season',lst41), ('Value',lst42)])).plot(kind='bar',x='Season',y='Value',ylim=((min(lst42))*0.97,max(lst42)*1.03))
plt.show()
# Out:
# Autumn: 0.253129346314

# %% [markdown]
# ** 5. Удалить строки данных, в которых для метеоритов не указана скорость.**

# %%
df5 = df.copy()
df5 = df5.dropna(subset=['Velocity (km/s)'])
df5.shape
# Out:
# (157, 10)

# %% [markdown]
# ** 6. Построить график, на котором по оси ОХ отложено время суток, по OY – частота появления метеоритов.**

# %%
def func61(self):
    return str(self['Peak Brightness Date/Time (UT)'])[11:13]
def func62(self):
    return int(self['Peak Brightness Date/Time (UT)'])/len(df)

df6 = df.copy()
df6['Peak Brightness Date/Time (UT)'] = df6.apply(func61,axis=1)
df6 = df6.groupby('Peak Brightness Date/Time (UT)')[['Peak Brightness Date/Time (UT)']].count()
df6['Peak Brightness Date/Time (UT)'] = df6.apply(func62,axis=1)
df6.plot(kind='bar',legend=None)
plt.show()

# %% [markdown]
# ** 7. Заполните строки в которых для метеоритов не указана скорость.**

# %%
df7 = df.copy()
df7['Velocity (km/s)'] = df7['Velocity (km/s)'].fillna(np.random.uniform(low=df7['Velocity (km/s)'].min(),high=df7['Velocity (km/s)'].max()))
df7
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2017-07-31 22:01:35           24.7N           118.5W
# 1              2017-07-23 06:12:38            6.6S            69.7W
# 2              2017-07-13 09:30:36           23.1N            60.7E
# 3              2017-06-30 14:26:45           34.3S           134.5E
# 4              2017-06-23 20:21:55           57.0N           143.7E
# 5              2017-06-20 13:41:32           54.2S           133.0E
# 6              2017-05-24 07:03:03            9.1S           101.8E
# 7              2017-05-22 17:44:39           49.6S           157.6W
# 8              2017-05-14 09:30:35           26.0S            32.4E
# 9              2017-04-30 21:28:28           25.7S            56.2E
# 10             2017-03-11 04:51:21           28.3N            60.2W
# 11             2017-03-09 04:16:37           40.5N            18.0W
# 12             2017-03-08 22:21:59           26.1S           174.9E
# ...

# %% [markdown]
# ** 8. Определить месяц года, для которого появление метеоритов наиболее вероятно (построить необходимые графики).**

# %%
def func8(self):
    return str(self['Peak Brightness Date/Time (UT)'])[5:7]

df8 = df.copy()
df8['Peak Brightness Date/Time (UT)'] = df.apply(func8,axis=1)
df8 = df8.groupby('Peak Brightness Date/Time (UT)')[['Peak Brightness Date/Time (UT)']].count()
df8 = df8.sort_values(by='Peak Brightness Date/Time (UT)',ascending=False)
print('Minimum: month №' + str(df8.index[0]))
df8.plot(kind='bar',legend=None,ylim=(min(df8['Peak Brightness Date/Time (UT)']*0.9),max(df8['Peak Brightness Date/Time (UT)']*1.1)))
plt.show()
# Out:
# Minimum: month №10
