# %% [markdown]
# # Лабораторная работа по машинному обучению
# ## Выполнил студент группы 15-В-1 Суворкин Павел
# ## Вариант 6 (Индекс счастья)
# ## Цель лабораторной работы – получение навыков работы с библиотеками анализа данных, предварительной обработки данных, средствами визуализации.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_2015 = pd.read_csv("2015.csv")
df_2016 = pd.read_csv("2016.csv")
df_2017 = pd.read_csv("2017.csv")

# %%
df_15 = pd.read_csv('2015.csv')
df_15.shape
# Out:
# (158, 12)

# %%
df_15 = df_15.dropna()
df_15 = df_15.drop_duplicates()
df_15 = df_15.reset_index(drop=True)

# %%
df_15.shape
# Out:
# (158, 12)

# %%
df_15.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df_15.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
df_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df_15.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df_16 = pd.read_csv('2016.csv')
df_16.shape
# Out:
# (157, 13)

# %%
df_16.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %%
df_16.tail(10)
# Out:
#          Country                           Region  Happiness Rank  \
# 147   Madagascar               Sub-Saharan Africa             148
# 148     Tanzania               Sub-Saharan Africa             149
# 149      Liberia               Sub-Saharan Africa             150
# 150       Guinea               Sub-Saharan Africa             151
# 151       Rwanda               Sub-Saharan Africa             152
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 147            3.695                      3.621                      3.769
# 148            3.666                      3.561                      3.771
# ...

# %%
df_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
# Country                          157 non-null object
# Region                           157 non-null object
# Happiness Rank                   157 non-null int64
# Happiness Score                  157 non-null float64
# Lower Confidence Interval        157 non-null float64
# Upper Confidence Interval        157 non-null float64
# Economy (GDP per Capita)         157 non-null float64
# Family                           157 non-null float64
# Health (Life Expectancy)         157 non-null float64
# Freedom                          157 non-null float64
# Trust (Government Corruption)    157 non-null float64
# Generosity                       157 non-null float64
# Dystopia Residual                157 non-null float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.0+ KB

# %%
df_16.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
df_17 = pd.read_csv('2017.csv')
df_17.shape
# Out:
# (155, 12)

# %%
df_17.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
df_17.tail(10)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 145                     Yemen             146            3.593      3.692750
# 146               South Sudan             147            3.591      3.725539
# 147                   Liberia             148            3.533      3.653756
# 148                    Guinea             149            3.507      3.584428
# 149                      Togo             150            3.495      3.594038
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 145     3.493250                  0.591683  0.935382
# ...

# %%
df_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
# Country                          155 non-null object
# Happiness.Rank                   155 non-null int64
# Happiness.Score                  155 non-null float64
# Whisker.high                     155 non-null float64
# Whisker.low                      155 non-null float64
# Economy..GDP.per.Capita.         155 non-null float64
# Family                           155 non-null float64
# Health..Life.Expectancy.         155 non-null float64
# Freedom                          155 non-null float64
# Generosity                       155 non-null float64
# Trust..Government.Corruption.    155 non-null float64
# Dystopia.Residual                155 non-null float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.6+ KB

# %%
df_17.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %% [markdown]
# ### 1) Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.

# %%
corr_matrix = df_17.drop(['Country', 'Happiness.Rank', 'Happiness.Score'], axis=1).corr()
sns.heatmap(corr_matrix, annot=False, fmt='.1f')
print(corr_matrix);
plt.plot()
plt.show()
# Out:
#                                Whisker.high  Whisker.low  \
# Whisker.high                       1.000000     0.998036
# Whisker.low                        0.998036     1.000000
# Economy..GDP.per.Capita.           0.811868     0.812267
# Family                             0.750934     0.753767
# Health..Life.Expectancy.           0.776634     0.786385
# Freedom                            0.569907     0.569808
# Generosity                         0.155462     0.154904
# Trust..Government.Corruption.      0.426459     0.431223
# Dystopia.Residual                  0.478824     0.471505
#
#                                Economy..GDP.per.Capita.    Family  \
# Whisker.high                                   0.811868  0.750934
# Whisker.low                                    0.812267  0.753767
# Economy..GDP.per.Capita.                       1.000000  0.688296
# Family                                         0.688296  1.000000
# ...

# %% [markdown]
# ### Вывод: Из данной таблицы и её визуализации можно сделать вывод, что поля: Whisker-high и Whisker-low коррелируют, т.е. взаимосвязаны друг с другом(0.998). Некоторые признаки имеют достаточно сильную взаимосвязь:Health Life Expectancy и Economy GDP per Capita. Другие почти несвязанны, например: Dystopia.Residual и Generosity.

# %% [markdown]
# ### 2) Постройте график счастья по регионам, страны на графике должны представляться отдельными точками.

# %%
df_all = pd.DataFrame(df_15.sort_values(by='Region', ascending=False))
df_all = df_all.reset_index(drop=True)
plt.ylabel('Happiness Score')
x = 0
region = df_all['Region'][0]
_x = [0]
labels = [df_all['Region'][0]]
for i in range(0, df_15.last_valid_index()+1):
    if region is not df_all['Region'][i]:
        labels.append(df_all['Region'][i])
        region = df_all['Region'][i]
        x = x + 1
        _x.append(x)
    plt.plot(x, df_all['Happiness Score'][i], 'bo')
plt.xticks(_x, labels, rotation='vertical')
plt.show()

# %% [markdown]
# ### 3) Оцените количество счастья по годам по регионам.

# %%
df_15 = df_15.assign(year=pd.Series(15, index=df_15.index))
df_16 = df_16.assign(year=pd.Series(16, index=df_16.index))
df_all = pd.concat([df_15, df_16])
df_all = pd.DataFrame(df_all.sort_values(by='Country', ascending=True))
df_all = df_all.reset_index(drop=True)
df_all = pd.DataFrame(df_all.sort_values(by=['Region', 'Country'], ascending=[True, True]))
df_all = df_all.reset_index(drop=True)
mask = df_all.Country.groupby(df_all.Country).transform('value_counts') > 1
df_all = df_all[mask]
df_all[['Region', 'Happiness Score', 'year']]
# Out:
#                          Region  Happiness Score  year
# 0     Australia and New Zealand            7.284    15
# 1     Australia and New Zealand            7.313    16
# 2     Australia and New Zealand            7.334    16
# 3     Australia and New Zealand            7.286    15
# 4    Central and Eastern Europe            4.655    16
# 5    Central and Eastern Europe            4.959    15
# 6    Central and Eastern Europe            4.360    16
# 7    Central and Eastern Europe            4.350    15
# 8    Central and Eastern Europe            5.291    16
# 9    Central and Eastern Europe            5.212    15
# 10   Central and Eastern Europe            5.802    16
# 11   Central and Eastern Europe            5.813    15
# 12   Central and Eastern Europe            5.163    16
# 13   Central and Eastern Europe            4.949    15
# 14   Central and Eastern Europe            4.218    15
# 15   Central and Eastern Europe            4.217    16
# ...

# %% [markdown]
# ### 4) Определите наиболее сильно изменяющиеся параметры по разным странам в разные годы.

# %%
print(df_all[['Dystopia Residual', 'Economy (GDP per Capita)', 'Family', 'Freedom', 'Generosity',
              'Health (Life Expectancy)', 'Lower Confidence Interval', 'Standard Error',
              'Trust (Government Corruption)', 'Upper Confidence Interval']].idxmax(axis=1) + ' / ' + df_all['Country'] 
      + ' / ' + df_all['year'].apply(str))
# Out:
# 0                     Dystopia Residual / Australia / 15
# 1             Upper Confidence Interval / Australia / 16
# 2           Upper Confidence Interval / New Zealand / 16
# 3                   Dystopia Residual / New Zealand / 15
# 4               Upper Confidence Interval / Albania / 16
# 5                       Dystopia Residual / Albania / 15
# 6               Upper Confidence Interval / Armenia / 16
# 7                       Dystopia Residual / Armenia / 15
# 8            Upper Confidence Interval / Azerbaijan / 16
# 9                    Dystopia Residual / Azerbaijan / 15
# 10              Upper Confidence Interval / Belarus / 16
# 11                      Dystopia Residual / Belarus / 15
# 12     Upper Confidence Interval / Bosnia and Herzego...
# 13       Dystopia Residual / Bosnia and Herzegovina / 15
# 14                                Family / Bulgaria / 15
# 15             Upper Confidence Interval / Bulgaria / 16
# ...

# %% [markdown]
# ### 5. Определите страны, появляющиеся и исчезающие в рейтинге стран

# %%
df_all = pd.concat([df_15, df_16, df_17])
df_all = pd.DataFrame(df_all.sort_values(by='Country', ascending=True))
df_all = df_all.reset_index(drop=True)
df_all = df_all['Country'].drop_duplicates(keep=False)
df_all.reset_index(drop=True)
df_all
# Out:
# 114                    Djibouti
# 168     Hong Kong S.A.R., China
# 315                        Oman
# 340                 Puerto Rico
# 376           Somaliland Region
# 377           Somaliland region
# 397                   Swaziland
# 409    Taiwan Province of China
# Name: Country, dtype: object

# %% [markdown]
# ### 6. Удалите строки с пропущенными значениями

# %%
df_deleted = df_15.dropna()
df_deleted
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %% [markdown]
# ### 7. Вычислите корреляцию Пирсона и Спирмена между несколькими признаками. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков.

# %%
print(df_15[['Happiness Score', 'Freedom', 'Family']].corr(method='pearson'))
print(df_15[['Happiness Score', 'Freedom', 'Family']].corr(method='spearman'))
df_corr = pd.concat([df_15[['Happiness Score', 'Freedom', 'Family']].corr(method='pearson'),
                     df_15[['Happiness Score', 'Freedom', 'Family']].corr(method='spearman')])
df_corr.plot.bar()
plt.show()
# Out:
#                  Happiness Score   Freedom    Family
# Happiness Score         1.000000  0.568211  0.740605
# Freedom                 0.568211  1.000000  0.441518
# Family                  0.740605  0.441518  1.000000
#                  Happiness Score   Freedom    Family
# Happiness Score         1.000000  0.576352  0.770038
# Freedom                 0.576352  1.000000  0.528139
# Family                  0.770038  0.528139  1.000000

# %% [markdown]
# ### 8. Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
df_15 = df_15.assign(LifeScore=pd.Series(df_15['Trust (Government Corruption)']
                                             + df_15['Economy (GDP per Capita)'], index=df_15.index))
df_15
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %% [markdown]
# ### Вывод: проделав данную лабораторную работу на примера базы данных "счастье", я приобрёл навыки работы с Jupyter Notebook.  Узнал что такое корреляция и как её построить, научился удалять пустые строки и вычислять корреляцию Пирсона и Спирмена.
