# %% [markdown]
# # Лабораторная работа №1
# ## Вариант №2
# ### Выполнил Пухов Артём
# ### Группа 15-В-2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('flights.csv', nrows = 2000000)

# %%
df.shape
# Out:
# (2000000, 31)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
# 3            LAX                 MIA                   20      ...
# 4            SEA                 ANC                   25      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
# 1         741.0           -9.0         0          0                  NaN
# 2         811.0            5.0         0          0                  NaN
# 3         756.0           -9.0         0          0                  NaN
# 4         259.0          -21.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
# 3               NaN             NaN            NaN                  NaN
# 4               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1999995  2015      5    7            4      AA           2439      N3GPAA
# 1999996  2015      5    7            4      DL           1908      N138DL
# 1999997  2015      5    7            4      DL           1957       N3756
# 1999998  2015      5    7            4      DL           1211      N380DA
# 1999999  2015      5    7            4      AA           1464      N590AA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 1999995            DFW                 DCA                 2005
# 1999996            DTW                 SFO                 2005
# 1999997            SLC                 SEA                 2005
# 1999998            SLC                 LAX                 2005
# 1999999            DFW                 TUL                 2005
#
#              ...        ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 1999995      ...              2345.0          -22.0         0          0
# 1999996      ...              2213.0           -3.0         0          0
# 1999997      ...              2118.0           11.0         0          0
# 1999998      ...              2118.0           13.0         0          0
# 1999999      ...              2151.0           37.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 1999995                  NaN               NaN             NaN            NaN
# 1999996                  NaN               NaN             NaN            NaN
# 1999997                  NaN               NaN             NaN            NaN
# 1999998                  NaN               NaN             NaN            NaN
# 1999999                  NaN              30.0             0.0            4.0
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 1999995                  NaN            NaN
# 1999996                  NaN            NaN
# 1999997                  NaN            NaN
# 1999998                  NaN            NaN
# 1999999                  3.0            0.0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  2000000.0  2.000000e+06  2.000000e+06  2.000000e+06   2.000000e+06
# mean      2015.0  2.669390e+00  1.489377e+01  3.925292e+00   2.224098e+03
# std          0.0  1.229049e+00  8.862280e+00  1.980435e+00   1.784719e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  2.000000e+00  7.000000e+00  2.000000e+00   7.480000e+02
# 50%       2015.0  3.000000e+00  1.500000e+01  4.000000e+00   1.700000e+03
# 75%       2015.0  4.000000e+00  2.300000e+01  6.000000e+00   3.415000e+03
# max       2015.0  5.000000e+00  3.100000e+01  7.000000e+00   9.794000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         2.000000e+06    1.952792e+06     1.952792e+06  1.951752e+06
# mean          1.327786e+03    1.335835e+03     9.373353e+00  1.615499e+01
# std           4.774509e+02    4.889001e+02     3.664060e+01  9.213883e+00
# min           1.000000e+00    1.000000e+00    -6.800000e+01  1.000000e+00
# 25%           9.200000e+02    9.250000e+02    -5.000000e+00  1.100000e+01
# 50%           1.324000e+03    1.331000e+03    -1.000000e+00  1.400000e+01
# 75%           1.726000e+03    1.736000e+03     8.000000e+00  1.900000e+01
# max           2.359000e+03    2.400000e+03     1.988000e+03  2.250000e+02
#
#          WHEELS_OFF      ...        SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# count  1.951752e+06      ...             2.000000e+06  1.950266e+06
# mean   1.358810e+03      ...             1.501282e+03  1.486731e+03
# std    4.896392e+02      ...             4.975229e+02  5.161146e+02
# min    1.000000e+00      ...             1.000000e+00  1.000000e+00
# 25%    9.400000e+02      ...             1.115000e+03  1.108000e+03
# 50%    1.344000e+03      ...             1.524000e+03  1.519000e+03
# 75%    1.750000e+03      ...             1.918000e+03  1.918000e+03
# max    2.400000e+03      ...             2.400000e+03  2.400000e+03
#
#        ARRIVAL_DELAY      DIVERTED     CANCELLED  AIR_SYSTEM_DELAY  \
# count   1.946636e+06  2.000000e+06  2.000000e+06     382299.000000
# mean    5.034904e+00  2.357000e-03  2.432500e-02         13.363488
# std     3.914823e+01  4.849171e-02  1.540562e-01         26.328539
# min    -8.700000e+01  0.000000e+00  0.000000e+00          0.000000
# 25%    -1.300000e+01  0.000000e+00  0.000000e+00          0.000000
# 50%    -4.000000e+00  0.000000e+00  0.000000e+00          3.000000
# 75%     9.000000e+00  0.000000e+00  0.000000e+00         18.000000
# max     1.971000e+03  1.000000e+00  1.000000e+00       1101.000000
#
#        SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# count   382299.000000  382299.000000        382299.000000  382299.000000
# mean         0.059276      18.348021            22.372080       2.987682
# std          1.859226      46.491821            41.673224      21.125054
# min          0.000000       0.000000             0.000000       0.000000
# 25%          0.000000       0.000000             0.000000       0.000000
# 50%          0.000000       2.000000             3.000000       0.000000
# 75%          0.000000      18.000000            28.000000       0.000000
# max        241.000000    1971.000000          1313.000000    1152.000000
#
# [8 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 31 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 473.0+ MB

# %% [markdown]
# #  1. Подсчитайте количество отменённых рейсов.

# %%
print(len(df[df['CANCELLED'] == 1]))
# Out:
# 48650

# %% [markdown]
# # 2. Определите аэропорт, рейсы для которого отменяются наиболее часто.

# %%
df1 = df.groupby('ORIGIN_AIRPORT')['CANCELLED'].sum().sort_values() 
print("Наиболее часто рейсы отменяют в аэропорте " + str(df1.index[len(df1)-1]))
# Out:
# Наиболее часто рейсы отменяют в аэропорте ORD

# %% [markdown]
# # 3. Определите корреляцию между отменой рейса и днём недели, месяцем, авиакомпанией, аэропортом.

# %%
from sklearn.preprocessing import LabelEncoder 

lb_make = LabelEncoder() 
df["AIRLINE"] = lb_make.fit_transform(df["AIRLINE"]) 
df["ORIGIN_AIRPORT"] = lb_make.fit_transform(df["ORIGIN_AIRPORT"])

# %%
df['CANCELLED'] = df['CANCELLED'].astype('float')
df['MONTH'] = df['MONTH'].astype('float')
df['DAY'] = df['DAY'].astype('float')
df['DAY_OF_WEEK'] = df['DAY_OF_WEEK'].astype('float')
df[['CANCELLED',  'MONTH','DAY' , 'DAY_OF_WEEK' , 'AIRLINE' , 'ORIGIN_AIRPORT']].info()

correlation = df[['CANCELLED',  'MONTH' , 'DAY' , 'DAY_OF_WEEK' , 'AIRLINE' , 'ORIGIN_AIRPORT']].corr(method = 'spearman')

sns.heatmap(correlation)
print(correlation)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 6 columns):
# CANCELLED         float64
# MONTH             float64
# DAY               float64
# DAY_OF_WEEK       float64
# AIRLINE           int64
# ORIGIN_AIRPORT    int64
# dtypes: float64(4), int64(2)
# memory usage: 91.6 MB
#                 CANCELLED     MONTH       DAY  DAY_OF_WEEK   AIRLINE  \
# CANCELLED        1.000000 -0.060431 -0.022646    -0.026842 -0.008954
# MONTH           -0.060431  1.000000 -0.119603    -0.021420  0.001647
# DAY             -0.022646 -0.119603  1.000000    -0.024280  0.000716
# DAY_OF_WEEK     -0.026842 -0.021420 -0.024280     1.000000 -0.008356
# AIRLINE         -0.008954  0.001647  0.000716    -0.008356  1.000000
# ORIGIN_AIRPORT  -0.016936  0.001805 -0.000458     0.004695  0.071840
#
#                 ORIGIN_AIRPORT
# CANCELLED            -0.016936
# MONTH                 0.001805
# DAY                  -0.000458
# DAY_OF_WEEK           0.004695
# AIRLINE               0.071840
# ORIGIN_AIRPORT        1.000000

# %%
df['MONTH'].unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.])

# %%
m1 = df[['CANCELLED', 'DAY_OF_WEEK', 'MONTH', 'AIRLINE', 'ORIGIN_AIRPORT']]
print(m1.shape)

m2 = m1.dropna()
print(m2.shape)
m2.isnull().any()
# Out:
# (2000000, 5)
# (2000000, 5)
# CANCELLED         False
# DAY_OF_WEEK       False
# MONTH             False
# AIRLINE           False
# ORIGIN_AIRPORT    False
# dtype: bool

# %% [markdown]
# # 4. Подсчитать для каждой авиакомпании: количество рейсов,  количество отменённых рейсов, количество перенаправленных рейсов.

# %%
airline_list = df['AIRLINE'].unique()

print('Количество рейсов')
print(df['AIRLINE'].value_counts())

print('Отменённые рейсы')
for airline in airline_list:
    print('airline', airline, '\t', (len(df[(df['CANCELLED'] == 1) & (df['AIRLINE'] == airline)])))
          
print('Перенаправленные рейсы')    
for airline in airline_list:
    print('airline', airline, '\t', (len(df[(df['DIVERTED'] == 1) & (df['AIRLINE'] == airline)])))
# Out:
# Количество рейсов
# 13    430124
# 3     288467
# 4     209691
# 9     202881
# 0     184791
# 10    169289
# 11    138041
# 7     116508
# 2      90909
# 1      56920
# 8      37924
# 5      28502
# 6      26030
# 12     19923
# Name: AIRLINE, dtype: int64
# Отменённые рейсы
# airline 1 	 295
# airline 0 	 5280
# airline 11 	 3532
# airline 3 	 3048
# airline 8 	 607
# airline 10 	 3023
# airline 6 	 57
# airline 2 	 3009
# airline 9 	 4042
# airline 4 	 7803
# airline 7 	 9129
# airline 5 	 301
# airline 13 	 8214
# airline 12 	 310
# Перенаправленные рейсы
# airline 1 	 165
# airline 0 	 538
# airline 11 	 261
# airline 3 	 457
# airline 8 	 49
# airline 10 	 344
# airline 6 	 22
# airline 2 	 289
# airline 9 	 571
# airline 4 	 702
# airline 7 	 274
# airline 5 	 45
# airline 13 	 954
# airline 12 	 43

# %% [markdown]
# # 5. Определите скорость полёта для каждого рейса, скорость полёта среднюю для авиакомпании.

# %%
print('Рейс № Скорость полета для каждого рейса') 


df['speed'] = df['DISTANCE'] / (df['ARRIVAL_TIME'] - df['DEPARTURE_TIME']) 
print(df['speed']) 
print('') 
print('Средняя скорость полета авиакомпаний') 

df['sred_speed'] = df['speed'] / df['AIRLINE'] 

print(df['sred_speed'])
# Out:
# Рейс № Скорость полета для каждого рейса
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f132d77252ea> in <module>()
#       4
#       5
# ----> 6 df['speed'] = df['DISTANCE'] / (df['ARRIVAL_TIME'] - df['DEPARTURE_TIME'])
#       7 print(df['speed'])
#       8 print('')
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 6. Визуализировать тепловую карту частоты отмены рейсов . по одной оси – дни, по другой оси – рейс. Или что-то другое, аэропорт. Графиков будет много, для каждого аэропорта

# %%
Разрешили не делать
# Out:
#   File "<ipython-input-2-8ad01013048c>", line 1
#     Разрешили не делать
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 7. Посчитайте и визуализируйте время задержки, отправки и прибытия по каждому аэропорту.

# %%
df.groupby('ORIGIN_AIRPORT')['ORIGIN_AIRPORT','DEPARTURE_DELAY'].mean().dropna().plot(kind='bar') 
df.groupby('DESTINATION_AIRPORT')['DESTINATION_AIRPORT','ARRIVAL_DELAY'].mean().dropna().plot(kind='bar') 
plt.show()

# %% [markdown]
# # 8. Определите для каждого аэропорта и визуализируйте задержки по каждой причине.

# %%
df_air = df['AIR_SYSTEM_DELAY']
df_sec = df['SECURITY_DELAY']
df_airl = df['AIRLINE_DELAY']
df_late = df['LATE_AIRCRAFT_DELAY']
df_weat = df['WEATHER_DELAY']            

df_air = df_air.dropna().reset_index(drop=True)
df_sec = df_sec.dropna().reset_index(drop=True)
df_airl = df_airl.dropna().reset_index(drop=True)
df_late = df_late.dropna().reset_index(drop=True)
df_weat = df_weat.dropna().reset_index(drop=True)


df.groupby('AIRLINE')['AIRLINE','AIR_SYSTEM_DELAY'].mean().dropna().plot(kind='bar') 
df.groupby('AIRLINE')['AIRLINE','SECURITY_DELAY'].mean().dropna().plot(kind='bar')
df.groupby('AIRLINE')['AIRLINE','AIRLINE_DELAY'].mean().dropna().plot(kind='bar')
df.groupby('AIRLINE')['AIRLINE','LATE_AIRCRAFT_DELAY'].mean().dropna().plot(kind='bar')    
df.groupby('AIRLINE')['AIRLINE','WEATHER_DELAY'].mean().dropna().plot(kind='bar')
plt.legend()
plt.show()

# %% [markdown]
# # 9. Определите авиакомпанию с максимальными задержками рейсов по отправке и прибытию.

# %%
airline_list = df['AIRLINE'].unique()
import operator
print('Максимальные задержки рейсов по отправке')
delay_dict = {}
for airline in airline_list:
    delay = len(df[(df['DEPARTURE_DELAY'] == 1) & (df['AIRLINE'] == airline)])
    print('airline', airline, '\t', delay)
    delay_dict[airline] = delay
    
    
delay_dict = sorted(delay_dict.items(), key=operator.itemgetter(1))
print('max item: ', delay_dict[-1])

print('Максимальные задержки рейсов по прибытию')
delay_dict = {}
for airline in airline_list:
    delay = len(df[(df['ARRIVAL_DELAY'] == 1) & (df['AIRLINE'] == airline)])
    print('airline', airline, '\t', delay)
    delay_dict[airline] = delay
    
delay_dict = sorted(delay_dict.items(), key=operator.itemgetter(1))
print('max item: ', delay_dict[-1])
# Out:
# Максимальные задержки рейсов по отправке
# airline AS 	 2986
# airline AA 	 11490
# airline US 	 5426
# airline DL 	 18682
# airline NK 	 1565
# airline UA 	 13561
# airline HA 	 1544
# airline B6 	 3184
# airline OO 	 6868
# airline EV 	 7216
# airline MQ 	 3474
# airline F9 	 1039
# airline WN 	 31114
# airline VX 	 1238
# max item:  ('WN', 31114)
# Максимальные задержки рейсов по прибытию
# airline AS 	 2880
# airline AA 	 7604
# airline US 	 4269
# airline DL 	 10854
# airline NK 	 1402
# airline UA 	 6069
# airline HA 	 2083
# airline B6 	 2871
# airline OO 	 9031
# airline EV 	 8304
# airline MQ 	 3543
# airline F9 	 1233
# airline WN 	 18121
# airline VX 	 874
# max item:  ('WN', 18121)
