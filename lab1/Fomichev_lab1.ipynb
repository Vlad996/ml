# %% [markdown]
# # Лабораторная работа по машинному обучению №1
# ## Выполнил студент группы 15-В-1 Фомичев Антон
# ## Вариант 3 (Вторичный рынок машин)
# ## Цель лабораторной работы – получение навыков работы с библиотеками анализа данных, предварительной обработки данных, средствами визуализации.

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\autos.csv', encoding = 'latin1')
df
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# ...                     ...
# 371498  2016-03-11 15:50:38
# ...

# %%
df.shape
# Out:
# (371528, 20)

# %%
df.shape
# Out:
# (371528, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
# dateCrawled            371528 non-null object
# name                   371528 non-null object
# seller                 371528 non-null object
# offerType              371528 non-null object
# price                  371528 non-null int64
# abtest                 371528 non-null object
# vehicleType            333659 non-null object
# yearOfRegistration     371528 non-null int64
# gearbox                351319 non-null object
# powerPS                371528 non-null int64
# model                  351044 non-null object
# kilometer              371528 non-null int64
# monthOfRegistration    371528 non-null int64
# fuelType               338142 non-null object
# brand                  371528 non-null object
# notRepairedDamage      299468 non-null object
# dateCreated            371528 non-null object
# nrOfPictures           371528 non-null int64
# ...

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
df.tail()
# Out:
#                 dateCrawled                                          name  \
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# ...

# %%
df.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count        371528.000000      371528.0  371528.00000
# mean              5.734445           0.0   50820.66764
# std               3.712412           0.0   25799.08247
# min               0.000000           0.0    1067.00000
# 25%               3.000000           0.0   30459.00000
# ...

# %%
numerical_columns = [i for i in df.columns if df[i].dtype.name != 'object']
categorial_columns = [i for i in df.columns if df[i].dtype.name == 'object']

print('numerical: ', numerical_columns)
print('categorial: ', categorial_columns)
# Out:
# numerical:  ['price', 'yearOfRegistration', 'powerPS', 'kilometer', 'monthOfRegistration', 'nrOfPictures', 'postalCode']
# categorial:  ['dateCrawled', 'name', 'seller', 'offerType', 'abtest', 'vehicleType', 'gearbox', 'model', 'fuelType', 'brand', 'notRepairedDamage', 'dateCreated', 'lastSeen']

# %% [markdown]
# ## 1. Удалите столбцы, ценность которых для оценки стоимости машины низка

# %%
df = df.drop(['dateCrawled','offerType','dateCreated','postalCode','lastSeen'], axis = 1)

# %%
df.count()
# Out:
# name                   371528
# seller                 371528
# price                  371528
# abtest                 371528
# vehicleType            333659
# yearOfRegistration     371528
# gearbox                351319
# powerPS                371528
# model                  351044
# kilometer              371528
# monthOfRegistration    371528
# fuelType               338142
# brand                  371528
# notRepairedDamage      299468
# nrOfPictures           371528
# dtype: int64

# %% [markdown]
# ## 2. Удалите повторяющиеся строки, строки содержащие пропуски в данных

# %%
df.shape
# Out:
# (371528, 15)

# %%
df = df.dropna()
df = df.drop_duplicates()
#df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (256901, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256901 entries, 3 to 371527
# Data columns (total 15 columns):
# name                   256901 non-null object
# seller                 256901 non-null object
# price                  256901 non-null int64
# abtest                 256901 non-null object
# vehicleType            256901 non-null object
# yearOfRegistration     256901 non-null int64
# gearbox                256901 non-null object
# powerPS                256901 non-null int64
# model                  256901 non-null object
# kilometer              256901 non-null int64
# monthOfRegistration    256901 non-null int64
# fuelType               256901 non-null object
# brand                  256901 non-null object
# notRepairedDamage      256901 non-null object
# nrOfPictures           256901 non-null int64
# dtypes: int64(6), object(9)
# memory usage: 31.4+ MB

# %% [markdown]
# ## 3.  Удалите данные в столбцах, выходящие за некоторые пределы (год регистрации, цена, мощность двигателя)

# %%
df = df[(df.yearOfRegistration > 2010) & (df.yearOfRegistration<2015)]
df = df[(df.price > 20000) & (df.price < 70000)]
df = df[(df.powerPS > 110) & (df.powerPS < 150)]
df
# Out:
#                                                      name  seller  price  \
# 98       BMW_318d_Aut.__Xenon__Navi__Sportsitze_FESTREIS!  privat  23490
# 272     Volkswagen_Caravelle_Lang_DSG_Navi_Standheiz._...  privat  26999
# 754           VW_T5_Multivan_Special__AHK__Fahrradtraeger  privat  28300
# 1740                  Audi_A3_1.4_TFSI_Limousine_S_tronic  privat  22900
# 2066    Volkswagen_T5_California_Beach__gepflegt_aus_1...  privat  35890
# 2119                Audi_A4_Avant_2.0_TDI_DPF_multitronic  privat  29999
# 2564                                    Volkswagen_Passat  privat  20500
# 2604       Volkswagen_T5_Multivan_Startline_2_0_TDI_114PS  privat  28500
# 3353    Land_Rover_Def.110_1._Hand_Topzustand_Volllede...  privat  43550
# 3457    Audi_A3_Sportback_S_line_1.4_TFSI_Xenon_B&O_Kl...  privat  21800
# 4355                                             Audi__Q3  privat  29500
# 4584           Volkswagen_Tiguan_2.0_TDI_DPF_4Motion_Life  privat  23950
# ...

# %% [markdown]
# ## 4. Заполнить пропущенные данные в строковых полях.

# %% [markdown]
# #### Пропущенных данных нет.

# %% [markdown]
# ## 5. Постройте гистограмму для типов коробок передач.

# %%
sns.countplot(data=df, y='gearbox')
plt.show()

# %% [markdown]
# ## 6. Постройте гистограмму по маркам автомобилей

# %%
sns.countplot(data=df, y='brand')
plt.show()

# %% [markdown]
# ## 7. Постройте гистограмму по типам кузова.

# %%
sns.countplot(data=df, y='vehicleType')
plt.show()

# %% [markdown]
# ## 8. Постройте гистограмму по используемому топливу.

# %%
sns.countplot(data=df, y='fuelType')
plt.show()

# %% [markdown]
# ## 9. Добавьте в данные новый признак, который представляет собой длину названия автомобиля.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1131 entries, 98 to 371483
# Data columns (total 15 columns):
# name                   1131 non-null object
# seller                 1131 non-null object
# price                  1131 non-null int64
# abtest                 1131 non-null object
# vehicleType            1131 non-null object
# yearOfRegistration     1131 non-null int64
# gearbox                1131 non-null object
# powerPS                1131 non-null int64
# model                  1131 non-null object
# kilometer              1131 non-null int64
# monthOfRegistration    1131 non-null int64
# fuelType               1131 non-null object
# brand                  1131 non-null object
# notRepairedDamage      1131 non-null object
# nrOfPictures           1131 non-null int64
# dtypes: int64(6), object(9)
# memory usage: 181.4+ KB

# %%
df1 = str(df['name'])[:3659].split('\n')
for i in df1:
    i = i[6:]
    i = i.strip()
    print(i)
    print(len(i))
    df1 = df.assign(longname=pd.Series(len(i), index = df.index))
df1
# Out:
# BMW_318d_Aut.__Xenon__Navi__Sportsitze_FESTREIS!
# 48
# Volkswagen_Caravelle_Lang_DSG_Navi_Standheiz._...
# 49
# VW_T5_Multivan_Special__AHK__Fahrradtraeger
# 43
# Audi_A3_1.4_TFSI_Limousine_S_tronic
# 35
# Volkswagen_T5_California_Beach__gepflegt_aus_1...
# 49
# Audi_A4_Avant_2.0_TDI_DPF_multitronic
# 37
# Volkswagen_Passat
# 17
# Volkswagen_T5_Multivan_Startline_2_0_TDI_114PS
# 46
# Land_Rover_Def.110_1._Hand_Topzustand_Volllede...
# 49
# Audi_A3_Sportback_S_line_1.4_TFSI_Xenon_B&O_Kl...
# 49
# Audi__Q3
# 8
# Volkswagen_Tiguan_2.0_TDI_DPF_4Motion_Life
# 42
# Golf_Cabrio_2.0l_TDI_BMT_Automatic
# 34
# Volkswagen__Golf_Cabriolet_Exclusive
# 36
# Volkswagen_Sharan_2.0_TDI_4Motion_BlueMotion__...
# 49
# Volkswagen_T5_California_Beach_TDI_4_Motion
# 43
# BMW_BMW_118i_Cabrio_Aut._Leder_fast_Vollaussta...
# 49
# Renault_Megane_Energy_dCi_130_Start_&_Stop_FAP...
# 49
# Volkswagen_Multivan_Kurz
# 24
# Mercedes_Benz_A_180__BlueEFFICIENCY__AMG_Sport
# 46
# BMW_118d
# 8
# BMW_318d_Touring_Aut.
# ...

# %% [markdown]
# ## 10. Постройте карту корреляций между признаками.

# %%
correlation_heatmap = df.corr()
sns.heatmap(correlation_heatmap, cmap = 'YlGnBu', annot=False, fmt='.1f')
plt.plot()
plt.show()
